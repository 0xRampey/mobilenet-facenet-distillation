# %% [markdown]
# ## Going to start off by testing Facenet's embeddings

# %%
import ipynb.fs #Boilerplate for import ipynb.fs #Boilerplate for ipynb botebooks as modules

import tensorflow as tf
import numpy as np
import sklearn
from utils import facenet
import os
import sys
import math
import imageio
# Out:
# /home/prudhvi/.conda/envs/tensorflow/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/prudhvi/.conda/envs/tensorflow/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/prudhvi/.conda/envs/tensorflow/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/prudhvi/.conda/envs/tensorflow/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data_path = 'tfrecords2'
record_iterator = tf.python_io.tf_record_iterator(path=data_path)

for string_record in record_iterator:
    
    example = tf.train.Example()
    example.ParseFromString(string_record)
    
    emb = example.features.feature['embedding'].float_list.value
    
    img_string = (example.features.feature['image_name_path']
                                  .bytes_list
                                  .value[0])
    embed = np.asarray(emb).reshape((512,))
    print(img_string)
# Out:
# b'AJ_Cook/AJ_Cook_0001.png'
# b'AJ_Lamas/AJ_Lamas_0001.png'
# b'Aaron_Eckhart/Aaron_Eckhart_0001.png'
# b'Aaron_Guiel/Aaron_Guiel_0001.png'
# b'Aaron_Patterson/Aaron_Patterson_0001.png'
# b'Aaron_Peirsol/Aaron_Peirsol_0001.png'
# b'Aaron_Peirsol/Aaron_Peirsol_0002.png'
# b'Aaron_Peirsol/Aaron_Peirsol_0003.png'
# b'Aaron_Peirsol/Aaron_Peirsol_0004.png'
# b'Aaron_Pena/Aaron_Pena_0001.png'
# b'Aaron_Sorkin/Aaron_Sorkin_0001.png'
# b'Aaron_Sorkin/Aaron_Sorkin_0002.png'
# b'Aaron_Tippin/Aaron_Tippin_0001.png'
# b'Abba_Eban/Abba_Eban_0001.png'
# b'Abbas_Kiarostami/Abbas_Kiarostami_0001.png'
# b'Abdel_Aziz_Al-Hakim/Abdel_Aziz_Al-Hakim_0001.png'
# b'Abdel_Madi_Shabneh/Abdel_Madi_Shabneh_0001.png'
# b'Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0001.png'
# b'Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0002.png'
# b'Abdoulaye_Wade/Abdoulaye_Wade_0003.png'
# b'Abdoulaye_Wade/Abdoulaye_Wade_0004.png'
# b'Abdoulaye_Wade/Abdoulaye_Wade_0001.png'
# b'Abdoulaye_Wade/Abdoulaye_Wade_0002.png'
# ...
